# %%
#Desiscion tree classifier
import numpy as np
from collections import Counter

# %%
def gini(y):
    counts = Counter(y)
    impurity = 1.0
    for label in counts:
        prob_of_lbl = counts[label] / len(y)
        impurity -= prob_of_lbl **2 
    return impurity

# %%
def split_dataset(X, y, feature_index, threshold)
